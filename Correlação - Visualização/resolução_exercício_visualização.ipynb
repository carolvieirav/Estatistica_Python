# %% [markdown]
# <a href="https://colab.research.google.com/github/carolvieirav/Estatistica_Python/blob/main/Correla%C3%A7%C3%A3o%20-%20Visualiza%C3%A7%C3%A3o/resolu%C3%A7%C3%A3o_exerc%C3%ADcio_visualiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício

# %% [markdown]
# https://www.kaggle.com/mustafaali96/weight-height

# %% [markdown]
# Variáveis usadas:
# * Money
# * Height
# * Weight
# * Gender

# %%
# importe as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Leia o dataset `weight-height-money.csv`.
#
# Examine as primeiras linhas do dataset

# %%
# seu código aqui
data = pd.read_csv('/content/weight-height.csv')

data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# Use o método **Describe** para descrever seus dados

# %%
# seu código aqui
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# O que você consegue observar? Compare a média e a mediana pra cada variável do dataset

# %%
# seu código aqui
'''


Height e weight: médias é medianas bem perto uma da outra


'''

# %% [markdown]
# Consegue imaginar qual tipo de distribuição cada variável terá?
#
# Tente prever qual categoria cada variável terá (antes de plotar o gráfico)!
# - assimétrica para esquerda
# - assimétrica para direita
# - Gaussiana
#
# dica: Lembre-se do efeito do outlier nos valores da média e mediana

# %%
# sua resposta aqui
'''


Height e weight: parecida com a guassiana


'''

# %% [markdown]
# Use scatterplot para checar a relação entre Height e Weight

# %%
# seu código aqui
plt.figure(figsize=(12, 8))

sns.scatterplot(x = 'Height', y = 'Weight', data = data)

# %% [markdown]
# Execute o mesmo gráfico mas mude a cor(hue) pelo gênero

# %%
# seu código aqui
plt.figure(figsize=(12, 8))

sns.scatterplot(x = 'Height', y = 'Weight', data = data, hue = 'Gender')

# %% [markdown]
# Quais insights plotar o hue pela variável gênero trouxe?

# %%
# seu código aqui

# %% [markdown]
# Crie a variável chamada `gender_groupby` para agrupar por 'Gender'.

# %%
# seu código aqui
gender_groupby = data.groupby('Gender')

# %% [markdown]
# Execute  `gender_groupby.head()`para checar os grupos obtidos.

# %%
# seu código aqui
gender_groupby.head()
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407

# %% [markdown]
# Execute gender_groupby.describe() para checar a estatísticas de cada grupo.

# %%
# seu código aqui
gender_groupby.describe().T
# Out:
# Gender             Female         Male
# Height count  5000.000000  5000.000000
#        mean     63.708774    69.026346
#        std       2.696284     2.863362
#        min      54.263133    58.406905
#        25%      61.894441    67.174679
#        50%      63.730924    69.027709
#        75%      65.563565    70.988744
#        max      73.389586    78.998742
# Weight count  5000.000000  5000.000000
#        mean    135.860093   187.020621
#        std      19.022468    19.781155
#        min      64.700127   112.902939
#        25%     122.934096   173.887767
#        50%     136.117583   187.033546
#        75%     148.810926   200.357802
#        max     202.237214   269.989699

# %% [markdown]
# Os resultados acima devem fornecer algumas informações sobre o efeito do gênero em seu conjunto de dados, tanto visual quanto numericamente.

# %% [markdown]
# ### Verificando a distribuição de suas variáveis ​​para cada Gênero.

# %% [markdown]
# Primeiro, plote a distribuição da variável `Height` novamente.

# %%
# seu código aqui
sns.distplot(data['Height'])

# %% [markdown]
# Agora, filtre seu conjunto de dados para cada gênero. Crie um dataframe chamado `men` e outro chamado `women` e plote a distribuição `Height` para cada um deles no mesmo gráfico.

# %%
# seu código aqui
men = data[data['Gender'] == 'Male']
women = data[data['Gender'] == 'Female']

# %%
sns.distplot(men.Height)
sns.distplot(women.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Que insights você pode observar a partir disso? Qual é o impacto de `Gender` em `Height`

# %%
# sua resposta aqui

# %% [markdown]
# ### Boxplot

# %% [markdown]
# Gender vs Height
#
# Plote o boxplot considerando o eixo x como `Gender` e o eixo y como `Height`

# %%
# seu código aqui
plt.figure(figsize=(12, 8))

sns.boxplot(x = 'Gender', y = 'Height', data = data)

# %% [markdown]
# Das conclusões dos exercícios anteriores, você esperava que os bloxplots fossem como os acima?

# %%
# sua resposta aqui
